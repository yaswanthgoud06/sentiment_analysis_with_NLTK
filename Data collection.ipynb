# %%
from ntscraper import Nitter

# %%
pip install ntscraper
# Out:
# Collecting ntscraper
#   Downloading ntscraper-0.3.13-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: requests in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ntscraper) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ntscraper) (4.12.3)
# Requirement already satisfied: lxml in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ntscraper) (5.2.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->ntscraper) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from requests->ntscraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from requests->ntscraper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from requests->ntscraper) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from requests->ntscraper) (2024.2.2)
# Downloading ntscraper-0.3.13-py3-none-any.whl (11 kB)
# Installing collected packages: ntscraper
# Successfully installed ntscraper-0.3.13
# Note: you may need to restart the kernel to use updated packages.

# %%
scraper = Nitter(log_level = 1,skip_instance_check= False)
# Out:
# Testing instances: 100%|███████████████████████████████████████████████████████████████| 77/77 [01:19<00:00,  1.04s/it]

# %%
tweets = scraper.get_tweets('venkyreviews',mode= 'user', number=10000)
# Out:
# 13-Aug-24 11:00:38 - No instance specified, using random instance https://nitter.privacydev.net
# 13-Aug-24 11:00:43 - Current stats for venkyreviews: 19 tweets, 0 threads...
# 13-Aug-24 11:00:48 - Current stats for venkyreviews: 38 tweets, 0 threads...
# 13-Aug-24 11:00:52 - Current stats for venkyreviews: 57 tweets, 0 threads...
# 13-Aug-24 11:00:54 - Empty page on https://nitter.privacydev.net

# %%
from pprint import pprint

# %%
pprint(tweets)
# Out:
# {'threads': [],
#  'tweets': [{'date': 'Jul 19, 2024 · 12:25 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1814094270900658331#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 27,
#                        'likes': 508,
#                        'quotes': 25,
#                        'retweets': 51},
#              'text': '#Darling is a Rom-Com with no purpose or aim. The film '
#                      'tries to be light hearted and ends up providing a few '
#                      'laughs, but apart from that the film neither engages nor '
#                      'entertains. The comedy is artificial throughout which '
#                      'gives it a tedious feel. Nabha Natesh’s role irritates. '
#                      'Can easily skip this one!   Rating: 1.75/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jul 18, 2024 · 11:29 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1814080164189569395#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 5,
#                        'likes': 423,
#                        'quotes': 3,
#                        'retweets': 26},
#              'text': '#Darling Boring 1st Half!   The comedy is artificial and '
#                      'does not work at all so far. Storyline is very thin so '
#                      'far. Need a huge 2nd half to save this one.',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jul 18, 2024 · 10:00 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1814057768674095115#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 10,
#                        'likes': 2256,
#                        'quotes': 1,
#                        'retweets': 97},
#              'text': 'Showtime: #Darling',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jul 12, 2024 · 12:59 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1811565982592434690#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 301,
#                        'likes': 3779,
#                        'quotes': 503,
#                        'retweets': 706},
#              'text': '#Indian2 is an outdated and tedious movie. Though the '
#                      'movie tries to give honest messages, it’s done in a '
#                      'boring way with no proper emotion and drama at all.   '
#                      'Shankar tried to repeat the screenplay of his old movies '
#                      'but fails to recreate the magic big time. All of the '
#                      'emotions are completely artificial and feel like a '
#                      'serial drama. The film had a good start for about 20 '
#                      'minutes along with Senapathys entry but continues to go '
#                      'down hill after that.   The grandeur and production '
#                      'values are nice. Anirudh had no scope to give an '
#                      'impactful score. While you can atleast sit through the '
#                      'first half, the second half doesn’t give you that '
#                      'chance. Disaster! #Bharateeyudu2   Rating: 1.75/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jul 12, 2024 · 12:30 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1811558721501139413#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 51,
#                        'likes': 1221,
#                        'quotes': 47,
#                        'retweets': 64},
#              'text': '🙄🙄',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jul 11, 2024 · 11:54 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1811549687792431298#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 5,
#                        'likes': 600,
#                        'quotes': 11,
#                        'retweets': 60},
#              'text': 'Kamal Hassan is doing well. Grandeur and Production '
#                      'Values stand out in the first half. Anirudhs BGM is '
#                      'pretty ineffective so far.',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jul 11, 2024 · 11:51 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1811548914681610592#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 17,
#                        'likes': 1992,
#                        'quotes': 27,
#                        'retweets': 171},
#              'text': '#Indian2 Strictly Average 1st Half!   Film starts off '
#                      'well with building an emotional set-up but then goes '
#                      'down a predictable and routine path. So far reminds us '
#                      'of Shankars old screenplay structure but the routine '
#                      'screenplay style makes it less impactful. Needs a good '
#                      '2nd half #Bharateeyudu2',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jul 11, 2024 · 9:54 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1811519507766161658#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 15,
#                        'likes': 2979,
#                        'quotes': 8,
#                        'retweets': 180},
#              'text': 'Showtime: #Indian2 #Bharateeyudu2',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jun 26, 2024 · 10:04 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1806086096758919462#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 33,
#                        'likes': 2482,
#                        'quotes': 29,
#                        'retweets': 745},
#              'text': 'Kudos to the whole of team of Kalki for attempting to '
#                      'bring a never before movie for Indian Cinema.   Nag '
#                      'Ashwin showed signs of both brilliance and inexperience. '
#                      'He was brilliant in focusing on the visuals and the '
#                      'finer details world. However, it felt at times he '
#                      'couldn’t establish a proper drama and emotional connect '
#                      'which would’ve elevated the movie even further.   All '
#                      'the cameos expect Mrunal are wasted and Vijay '
#                      'Deverakondas cameo is very odd.   SaNA did a very good '
#                      'job with the BGM in certain places but in others it was '
#                      'just adequate.   Prabhas had limited screen time in this '
#                      'one but did a good job in a fun character and gives a '
#                      'big fan worthy sequence in the climax   The rest of the '
#                      'cast especially Amitabh and Deepika have done and take '
#                      'up majority of the screenspace.   #kalki2898AD #Kalki',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jun 26, 2024 · 9:56 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1806084212962783318#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 256,
#                        'likes': 8355,
#                        'quotes': 236,
#                        'retweets': 2209},
#              'text': '#Kalki2898AD is a larger than life Sci-FI Action '
#                      'Experience. The visuals and world building by Nag Ashwin '
#                      'are never before from Indian Cinema. However, Nag Ashwin '
#                      'shows some inexperience in building a proper drama and '
#                      'emotional connect with somewhat of a flat screenplay.   '
#                      'Still, he was able to manage a couple of very good '
#                      'blocks especially the climax which worked very well and '
#                      'is goosebumps worthy.   Despite some of its flaws, This '
#                      'is a movie that should be experienced on the big screen '
#                      'for the experience it offers!  Rating: 3/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jun 26, 2024 · 8:17 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1806059123554828563#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 46,
#                        'likes': 3304,
#                        'quotes': 39,
#                        'retweets': 816},
#              'text': 'Interval Block stands out the most from the 1st half 👍 '
#                      '#Kalki2898AD',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jun 26, 2024 · 8:02 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1806055441283043697#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 168,
#                        'likes': 9977,
#                        'quotes': 143,
#                        'retweets': 1259},
#              'text': '#Kalki2898AD Passable 1st Half!  The visuals and set up '
#                      'is something that has not been seen from Indian cinema '
#                      'which is captivating along with an interesting '
#                      'storyline. However, the screenplay is done in a mostly '
#                      'flat way so far. Prabhas has a fun character but limited '
#                      'screen time so far. Seems like 1st half is just a set '
#                      'up.',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jun 26, 2024 · 6:14 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1806028221760098396#m',
#              'pictures': ['https://pbs.twimg.com/media/GRBNFqsX0AETgLa.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 203,
#                        'likes': 11584,
#                        'quotes': 127,
#                        'retweets': 1193},
#              'text': 'Showtime: #Kalki2898AD #Kalki',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jun 25, 2024 · 2:59 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1805616737171157444#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 25,
#                        'likes': 972,
#                        'quotes': 10,
#                        'retweets': 92},
#              'text': '#Indian2 Trailer makes very little impact. Reminiscent '
#                      'of movies that came over a decade ago and doesn’t offer '
#                      'much of a curiosity factor. Grandeur wise looks alright '
#                      'but the whole cut misses a much needed X-factor. '
#                      'Hopefully Shankar can deliver! #Bharateeyudu2',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jun 21, 2024 · 3:30 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1804175086758343017#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 56,
#                        'likes': 3435,
#                        'quotes': 20,
#                        'retweets': 1042},
#              'text': '#KALKI2898AD\u200c 2nd Trailer cut delivers again '
#                      'showing the visual spectacle world of Kalki in a grand '
#                      'manner. Gives a good glimpse into the drama/emotion that '
#                      'will unfold. Only gripe is the background music which is '
#                      'subpar and not effective at all but expecting SaNa to '
#                      'deliver in the movie. Raised curiosity levels!',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jun 7, 2024 · 1:13 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1798885855127609361#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 27,
#                        'likes': 676,
#                        'quotes': 24,
#                        'retweets': 60},
#              'text': '#Manamey is an inferior movie that tries to fall into '
#                      'the feel good family/love drama template. The 1st half '
#                      'is watchable with some light hearted comedy that '
#                      'somewhat works. However, the 2nd half goes on endlessly '
#                      'without any impactful scenes. The emotional connect '
#                      'needed for this genre is missing coupled with '
#                      'underwritten characterizations. Not up to the mark!   '
#                      'Rating: 2.25/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jun 6, 2024 · 9:20 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1798827255348740383#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 8,
#                        'likes': 1046,
#                        'quotes': 2,
#                        'retweets': 51},
#              'text': 'Showtime: #Manamey',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'May 31, 2024 · 1:07 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1796347665355026778#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 46,
#                        'likes': 963,
#                        'quotes': 41,
#                        'retweets': 105},
#              'text': '#GangsofGodavari is a below par rural gangster drama '
#                      'that had potential with its set up but falters in '
#                      'execution. The first half is watchable with a couple of '
#                      'good mass blocks. However, the screenplay is narrated '
#                      'with a choppy edit that fails to build a proper drama '
#                      'and emotion. The second half goes for a toss with '
#                      'nothing much to mention. Disappointing!   Rating: 2.25/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'May 30, 2024 · 10:37 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1796310022999433554#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 9,
#                        'likes': 1954,
#                        'quotes': 1,
#                        'retweets': 79},
#              'text': 'Showtime: #GangsofGodavari',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'May 30, 2024 · 7:15 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1796259109592789493#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 54,
#                        'likes': 3866,
#                        'quotes': 16,
#                        'retweets': 1342},
#              'text': '#BujjiAndBhairava hints at a one of a kind futuristic '
#                      'set up that has not been seen from Indian cinema. These '
#                      'few episodes are more on the fun side but the massive '
#                      'ambition the team has is clearly seen. If the prelude '
#                      'vibe can be translated on the big screen then sky is the '
#                      'limit. This one definitely raises expectations 👍 '
#                      '#Kalki2898AD',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'May 25, 2024 · 12:48 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1794168636287996381#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 16,
#                        'likes': 432,
#                        'quotes': 18,
#                        'retweets': 37},
#              'text': '#LoveMe is a silly ghost themed loved story that had an '
#                      'interesting core idea but the execution is mostly bad. '
#                      'The director fails to create suspense apart from a few '
#                      'bits in both halves and the screenplay is unconvincing '
#                      'and confusing at times. Music is ineffective. Nothing '
#                      'much else to mention.   Rating: 1.75/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'May 24, 2024 · 9:58 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1794125803745136798#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 6,
#                        'likes': 1054,
#                        'quotes': 4,
#                        'retweets': 33},
#              'text': 'Showtime: #LoveMe',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Apr 13, 2024 · 6:57 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1779041322369798205#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 5,
#                        'likes': 258,
#                        'quotes': 4,
#                        'retweets': 26},
#              'text': '#Chamkila is a captivating biopic that leaves a lasting '
#                      'impact. Apart from a few flaws and some pacing issues, '
#                      'the narration of Amar Singh Chamkilas life is done in a '
#                      'mostly engaging way with Imtiaz Ali’s mark all over '
#                      'making you reflect on society. Diljit and Parineeti were '
#                      'excellent. Easily one of the better biopics to come from '
#                      'Indian Cinema. Go check it out on Netflix! '
#                      '#AmarSinghChamkila',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Apr 13, 2024 · 1:34 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1778959893526921724#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 17,
#                        'likes': 1192,
#                        'quotes': 7,
#                        'retweets': 115},
#              'text': '#VarshangalkkuShesham is a drama full of soul and '
#                      'heartwarming moments throughout. It may not be '
#                      'everyone’s cup of tea and the runtime/slow paced  '
#                      'narration style is a problem at times but if you can get '
#                      'over that, it’s definitely a film that will take you on '
#                      'an emotional journey.   Vineeth Srinivasan has made '
#                      'another commendable film after Hridayam. Cinema fanatics '
#                      'will like this even more. Another praise worthy film '
#                      'from Malayalam Cinema!',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Apr 10, 2024 · 5:47 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1778117557196656940#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 86,
#                        'likes': 876,
#                        'quotes': 64,
#                        'retweets': 223},
#              'text': '#BadeMiyanChoteMiyan is a run-of-the-mill action film '
#                      'that is alright in parts but doesn’t offer anything '
#                      'new.   The film follows a beaten to death storyline of '
#                      'an antagonist being associated with Indian forces and '
#                      'getting betrayed thus seeking revenge.   The chemistry '
#                      'between Akshay and Tiger works well along with a few '
#                      'action blocks and Prithvirajs character.  However, the '
#                      'screenplay is predictable and doesn’t have a proper '
#                      'emotional connect and feels tiring after while as we’ve '
#                      'seen the same structure in many movies. Overall, a so-so '
#                      'time-pass film that is mostly forgettable. #BMCM   '
#                      'Rating: 2.5/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Apr 8, 2024 · 5:49 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1777212092245766188#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 43,
#                        'likes': 4105,
#                        'quotes': 14,
#                        'retweets': 1069},
#              'text': '#Pushpa2TheRule Teaser felt more like a glimpse but Allu '
#                      'Arjun’s avatar is absolutely BREATHTAKING!! Need a lot '
#                      'of guts to try a getup like that especially coming from '
#                      'Telugu Cinema. Wish they showed more content but '
#                      'definitely raises expectations and makes you look '
#                      'forward!',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Apr 4, 2024 · 9:41 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1776002159508647972#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 26,
#                        'likes': 735,
#                        'quotes': 73,
#                        'retweets': 129},
#              'text': 'It is high time that VD steps out of his comfort zone '
#                      'and stops doing these monotonous template roles. His '
#                      'performance and character worked very well in GG but in '
#                      'this it feels repetitive and leaves no impact at all.   '
#                      'Parasuram tried to copy the same template structure of '
#                      'GG but fails in recreating the same magic. There is a '
#                      'scene in America where American girls think VD is a '
#                      'prostitute and start attacking him in the middle of '
#                      'Times Square in New York… not sure what Parasuram was '
#                      'thinking when writing scenes like that.   #FamilyStar',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Apr 4, 2024 · 9:37 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1776001268634341735#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 54,
#                        'likes': 1565,
#                        'quotes': 131,
#                        'retweets': 273},
#              'text': '#FamilyStar is an inferior template rom-com family movie '
#                      'that has a few time-pass moments but no real emotional '
#                      'connection nor feel good moments.   First half is '
#                      'underwhelming and feels like a serial until the '
#                      'pre-interval. Second half starts on a more fun note but '
#                      'quickly turns uninteresting and preachy. Music is very '
#                      'ineffective. The blockbuster combo of GG disappoints. '
#                      'Below Par!    Rating: 2.25/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Apr 4, 2024 · 8:14 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1775980277061263521#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 86,
#                        'likes': 3255,
#                        'quotes': 85,
#                        'retweets': 379},
#              'text': '#FamilyStar Below Par 1st Half!   So far it has a slow '
#                      'serial like feel to it. Few moments are entertaining but '
#                      'has absolutely nothing new or noteworthy yet. Need a big '
#                      '2nd half!',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Apr 4, 2024 · 6:51 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1775959426802827730#m',
#              'pictures': ['https://pbs.twimg.com/media/GKV5rhYWQAA-KlQ.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 52,
#                        'likes': 1200,
#                        'quotes': 24,
#                        'retweets': 130},
#              'text': 'Showtime: #FamilyStar',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Apr 2, 2024 · 2:31 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1774987939434332401#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 16,
#                        'likes': 1133,
#                        'quotes': 15,
#                        'retweets': 323},
#              'text': '#TheGreatestOfAllTime North America Distribution Rights '
#                      'have been acquired by Hamsini Entertainment. Expected to '
#                      'be one of the biggest releases for Thalapathy Vijay🇺🇸 '
#                      '#GOAT  Previous High Budget North America Releases by '
#                      'Hamsini: Master, Pushpa, Beast, Valimai, and Devara '
#                      '(soon).',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Mar 29, 2024 · 1:47 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1773527467380093277#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 37,
#                        'likes': 1346,
#                        'quotes': 27,
#                        'retweets': 213},
#              'text': '#TilluSquare A Decent Entertainer that has fun moments '
#                      'throughout. Tillu’s characterization and one liners have '
#                      'worked well again in this one along with a few fun '
#                      'twists. While some of the comedy lands well, some of it '
#                      'feels repetitive and mundane at times. Nevertheless, a '
#                      'pretty lighthearted entertaining watch!   Rating: '
#                      '2.75-3/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Mar 29, 2024 · 12:31 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1773508286488154449#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 15,
#                        'likes': 3050,
#                        'quotes': 9,
#                        'retweets': 250},
#              'text': '#TilluSquare Decent 1st Half!  Siddhu is back again with '
#                      'his trademark energetic avatar and one liners that are '
#                      'carrying the film. Comedy works in parts so far but '
#                      'feels redundant at times . Fun interval twist sets up '
#                      'the 2nd half well.',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Mar 28, 2024 · 10:33 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1773478492333580508#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 3,
#                        'likes': 555,
#                        'quotes': 0,
#                        'retweets': 28},
#              'text': 'Showtime: #TilluSquare',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Mar 22, 2024 · 2:59 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1771008834800124033#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 18,
#                        'likes': 704,
#                        'quotes': 8,
#                        'retweets': 70},
#              'text': '#OmBheemBush is a passable comedy entertainer that is '
#                      'filled with contemporary references. Film runs solely on '
#                      'the trio, comic one liners, and a few hilarious blocks '
#                      'which work well. However, the storyline is almost '
#                      'non-existent which gives a lengthy feel to it and the '
#                      'film goes overboard in some places coupled with below '
#                      'par music. Leave aside logics and you can give this '
#                      'mindless comedy entertainer a try!   Rating: 2.75/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Mar 21, 2024 · 8:59 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1770918287825571856#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 22,
#                        'likes': 861,
#                        'quotes': 8,
#                        'retweets': 45},
#              'text': 'Showtime: #OmBheemBush',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Mar 10, 2024 · 5:18 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1766694989931642987#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 49,
#                        'likes': 1764,
#                        'quotes': 54,
#                        'retweets': 195},
#              'text': '#Premalu is a Breezy Rom-Com that is enjoyable '
#                      'throughout. It has a cliched feel to it and feels '
#                      'slightly dragged at times, but the lighthearted nature '
#                      'of the film keeps it entertaining from start to finish. '
#                      'Targeted towards the younger audience but can be watched '
#                      'with families as well. Fun watch!   Rating: 3/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Mar 9, 2024 · 2:01 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1766283058997514501#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 11,
#                        'likes': 1169,
#                        'quotes': 9,
#                        'retweets': 104},
#              'text': '#ManjummelBoys A Heartwarming Survival Thriller that '
#                      'takes time to get going but once it does it keeps you on '
#                      'the edge of your seat. Though there is a predictability '
#                      'factor, the narration keeps you engaged. Performances '
#                      'are outstanding. Good Watch!',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Mar 8, 2024 · 11:12 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1766240719486812275#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 3,
#                        'likes': 416,
#                        'quotes': 0,
#                        'retweets': 23},
#              'text': 'Showtime: #ManjummelBoys',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Mar 6, 2024 · 4:36 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1765416279542751419#m',
#              'pictures': ['https://pbs.twimg.com/media/GIAEv9OWkAAlwtS.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 17,
#                        'likes': 798,
#                        'quotes': 22,
#                        'retweets': 153},
#              'text': '#Hanuman North America Closing Reported Gross [Final]:  '
#                      '$5,312,935 - 496 Locations [₹44 Crores]  Historic '
#                      'Blockbuster! One of the biggest blockbusters in Telugu '
#                      'Cinema History!! 5th Highest Telugu Grosser of All-Time '
#                      'in North America.',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
# ...
#              'link': 'https://twitter.com/venkyreviews/status/1758213432812175781#m',
#              'pictures': ['https://pbs.twimg.com/media/GGZtzCZWMAAudO6.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 14,
#                        'likes': 804,
#                        'quotes': 14,
#                        'retweets': 158},
#              'text': '#Animal North America Closing Reported Gross [Final]:  '
#                      '$15,001,042 - 739 Locations [₹124.51 Crores]  One of the '
#                      'biggest blockbusters of Indian Cinema!! 3rd Highest '
#                      'Hindi Grosser of All-Time in North America. All-Time '
#                      'Record in Canada.',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Feb 9, 2024 · 2:07 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1755775430508847204#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 78,
#                        'likes': 1238,
#                        'quotes': 46,
#                        'retweets': 153},
#              'text': '#Eagle An Ordinary Action Thriller with a below average '
#                      '1st half but a better 2nd half which saves the film to '
#                      'an extent!   The action sequences in the 2nd half are '
#                      'the biggest USP for the film and have a come out well. '
#                      'Production Values and Cinematography stand out.  '
#                      'Director drew heavy inspiration from the style of Vikram '
#                      'and also a bit of KGF. What works in those movies, does '
#                      'not work much in this one because of the tiresome '
#                      'narration. BGM could’ve been better. Most dialogues feel '
#                      'like quotes thus evoke no emotion and get rather '
#                      'irritating.   Action scenes and the climax portions work '
#                      'but the rest is so-so.  Rating: 2.5/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Feb 9, 2024 · 12:16 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1755747395969675316#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 31,
#                        'likes': 1797,
#                        'quotes': 15,
#                        'retweets': 131},
#              'text': '#Eagle Below Average 1st half!  Interesting storyline '
#                      'being narrated in a tiresome way. Ravi Teja has limited '
#                      'screen time so far. Production Values are good.',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Feb 8, 2024 · 10:56 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1755727260814876828#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 6,
#                        'likes': 470,
#                        'quotes': 5,
#                        'retweets': 28},
#              'text': 'Showtime: #Eagle',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Feb 2, 2024 · 1:27 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1753228621995561013#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 37,
#                        'likes': 481,
#                        'quotes': 22,
#                        'retweets': 58},
#              'text': '#AmbajipetaMarriageBand A Predictable and Bland Village '
#                      'Drama that deals with a upper/lower class storyline. '
#                      'Director tried to tell this story in a honest way but '
#                      'the formulaic approach reminds us of many movies thus '
#                      'lacks moments that feel truly hard hitting or emotional. '
#                      'Good performances by the main leads stand out. A time '
#                      'pass OTT watch at best!   Rating: 2.25/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Feb 2, 2024 · 12:22 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1753212375140798669#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 8,
#                        'likes': 410,
#                        'quotes': 2,
#                        'retweets': 24},
#              'text': '#AmbajipetaMarriageBand Average 1st Half!  Engaging '
#                      'initial start but goes down the path of a template '
#                      'village drama that is predictable and bland. Good '
#                      'performances are holding the film together so far.',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Feb 1, 2024 · 11:00 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1753191678884647347#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 4,
#                        'likes': 584,
#                        'quotes': 1,
#                        'retweets': 29},
#              'text': 'Showtime: #AmbajipetaMarriageBand',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jan 12, 2024 · 6:14 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1745871945411760239#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 105,
#                        'likes': 2464,
#                        'quotes': 111,
#                        'retweets': 316},
#              'text': '#Saindhav A Stylish Action Drama with standout action '
#                      'sequences but the drama part falls flat!   The film has '
#                      'its heart in the right place but the narration is done '
#                      'in a flat way where there are very little highs and even '
#                      'when there is potential the music fails big time. SaNa’s '
#                      'BGM is the weakest part of the film and has lowered the '
#                      'impact of many scenes.  Few action sequences, good '
#                      'climax, and Venky’s performance in an action avatar '
#                      'standout but the rest is mediocre.   Rating: 2.5/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jan 12, 2024 · 4:56 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1745852220598345910#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 47,
#                        'likes': 4137,
#                        'quotes': 52,
#                        'retweets': 592},
#              'text': '#Saindhav Decent 1st Half!   First 30mins runs on a slow '
#                      'note but picks up after with an interesting storyline, '
#                      'good action sequences and performances. BGM had scope to '
#                      'be a lot better and is quite ineffective till now.',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jan 12, 2024 · 3:24 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1745829141755130034#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 58,
#                        'likes': 1837,
#                        'quotes': 57,
#                        'retweets': 236},
#              'text': 'Showtime: #Saindhav',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jan 12, 2024 · 2:36 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1745635846894551496#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 6,
#                        'likes': 1391,
#                        'quotes': 5,
#                        'retweets': 287},
#              'text': 'This movie will be a textbook on how to use  VFX with a '
#                      'limited budget and will inspire makers with smaller '
#                      'budget. Kudos to Director Prashanth Varma and the '
#                      'Producers for pulling off a subject like this. Teja '
#                      'Sajja has performed well and definitely has a bright '
#                      'future #Hanuman',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jan 12, 2024 · 2:33 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1745635051335819676#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 61,
#                        'likes': 3794,
#                        'quotes': 41,
#                        'retweets': 860},
#              'text': '#Hanuman A Well Made Superhero Story told with the '
#                      'element of Hanuman infused!   While the 1st half is '
#                      'engaging throughout, the 2nd half feels a little dragged '
#                      'at parts but the climax more than makes up for it. Very '
#                      'rare do we see a concept like this and the director has '
#                      'succeeded in pulling off a story like for the most part. '
#                      'BGM is good. Production Values and the VFX standout. '
#                      'Good Watch 👍  Rating: 3/5',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jan 12, 2024 · 12:57 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1745611027515871265#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 23,
#                        'likes': 3132,
#                        'quotes': 6,
#                        'retweets': 501},
#              'text': '#Hanuman Good 1st Half!  Director is doing a good job of '
#                      'mixing a superhero story with a Hanuman element while '
#                      'keeping commercial elements in tact. VFX is great.',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []},
#             {'date': 'Jan 11, 2024 · 11:30 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/venkyreviews/status/1745589024960487459#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 10,
#                        'likes': 513,
#                        'quotes': 1,
#                        'retweets': 40},
#              'text': 'Showtime: #Hanuman',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg',
#                       'name': 'Venky Reviews',
#                       'profile_id': '1654192566248656898',
#                       'username': '@venkyreviews'},
#              'videos': []}]}

# %%
tweets['tweets'][0]
# Out:
# {'link': 'https://twitter.com/venkyreviews/status/1814094270900658331#m',
#  'text': '#Darling is a Rom-Com with no purpose or aim. The film tries to be light hearted and ends up providing a few laughs, but apart from that the film neither engages nor entertains. The comedy is artificial throughout which gives it a tedious feel. Nabha Natesh’s role irritates. Can easily skip this one!   Rating: 1.75/5',
#  'user': {'name': 'Venky Reviews',
#   'username': '@venkyreviews',
#   'profile_id': '1654192566248656898',
#   'avatar': 'https://pbs.twimg.com/profile_images/1654192566248656898/yI9xzRRx_bigger.jpg'},
#  'date': 'Jul 19, 2024 · 12:25 AM UTC',
#  'is-retweet': False,
#  'is-pinned': False,
#  'external-link': '',
#  'replying-to': [],
#  'quoted-post': {},
#  'stats': {'comments': 27, 'retweets': 51, 'quotes': 25, 'likes': 508},
#  'pictures': [],
#  'videos': [],
#  'gifs': []}

# %%
pprint(bjp)
# Out:
# {'bio': "Welcome to official account of the world's largest Political Party of "
#         "the world's largest Democracy- BHARATIYA JANATA PARTY, भारतीय जनता "
#         'पार्टी.',
#  'id': '207809313',
#  'image': 'https://pbs.twimg.com/profile_images/1700102447061245952/OyNepKMe_400x400.jpg',
#  'joined': '2:19 AM - 26 Oct 2010',
#  'location': '6-A, Deen Dayal Upadhyay Marg,',
#  'name': 'BJP',
#  'stats': {'followers': 21742797,
#            'following': 3,
#            'likes': 0,
#            'media': 0,
#            'tweets': 260587},
#  'username': '@BJP4India',
#  'website': 'http://www.bjp.org'}

# %%
data = {
    'link':[],
    'text':[],
    'user':[],
    'date':[],
    'likes':[],
    'quotes':[],
    'retweets':[],
    'comments':[],
}
for tweet in tweets['tweets']:
    data['link'].append(tweet['link'])
    data['text'].append(tweet['text'])
    data['user'].append(tweet['user']['name'])
    data['date'].append(tweet['date'])
    data['likes'].append(tweet['stats']['likes'])
    data['quotes'].append(tweet['stats']['quotes'])
    data['retweets'].append(tweet['stats']['retweets'])
    data['comments'].append(tweet['stats']['comments'])

# %%
data
# Out:
# {'link': ['https://twitter.com/venkyreviews/status/1814094270900658331#m',
#   'https://twitter.com/venkyreviews/status/1814080164189569395#m',
#   'https://twitter.com/venkyreviews/status/1814057768674095115#m',
#   'https://twitter.com/venkyreviews/status/1811565982592434690#m',
#   'https://twitter.com/venkyreviews/status/1811558721501139413#m',
#   'https://twitter.com/venkyreviews/status/1811549687792431298#m',
#   'https://twitter.com/venkyreviews/status/1811548914681610592#m',
#   'https://twitter.com/venkyreviews/status/1811519507766161658#m',
#   'https://twitter.com/venkyreviews/status/1806086096758919462#m',
#   'https://twitter.com/venkyreviews/status/1806084212962783318#m',
#   'https://twitter.com/venkyreviews/status/1806059123554828563#m',
#   'https://twitter.com/venkyreviews/status/1806055441283043697#m',
#   'https://twitter.com/venkyreviews/status/1806028221760098396#m',
#   'https://twitter.com/venkyreviews/status/1805616737171157444#m',
#   'https://twitter.com/venkyreviews/status/1804175086758343017#m',
#   'https://twitter.com/venkyreviews/status/1798885855127609361#m',
#   'https://twitter.com/venkyreviews/status/1798827255348740383#m',
#   'https://twitter.com/venkyreviews/status/1796347665355026778#m',
#   'https://twitter.com/venkyreviews/status/1796310022999433554#m',
#   'https://twitter.com/venkyreviews/status/1796259109592789493#m',
#   'https://twitter.com/venkyreviews/status/1794168636287996381#m',
#   'https://twitter.com/venkyreviews/status/1794125803745136798#m',
#   'https://twitter.com/venkyreviews/status/1779041322369798205#m',
#   'https://twitter.com/venkyreviews/status/1778959893526921724#m',
#   'https://twitter.com/venkyreviews/status/1778117557196656940#m',
#   'https://twitter.com/venkyreviews/status/1777212092245766188#m',
#   'https://twitter.com/venkyreviews/status/1776002159508647972#m',
#   'https://twitter.com/venkyreviews/status/1776001268634341735#m',
#   'https://twitter.com/venkyreviews/status/1775980277061263521#m',
#   'https://twitter.com/venkyreviews/status/1775959426802827730#m',
#   'https://twitter.com/venkyreviews/status/1774987939434332401#m',
#   'https://twitter.com/venkyreviews/status/1773527467380093277#m',
#   'https://twitter.com/venkyreviews/status/1773508286488154449#m',
#   'https://twitter.com/venkyreviews/status/1773478492333580508#m',
#   'https://twitter.com/venkyreviews/status/1771008834800124033#m',
#   'https://twitter.com/venkyreviews/status/1770918287825571856#m',
#   'https://twitter.com/venkyreviews/status/1766694989931642987#m',
#   'https://twitter.com/venkyreviews/status/1766283058997514501#m',
#   'https://twitter.com/venkyreviews/status/1766240719486812275#m',
#   'https://twitter.com/venkyreviews/status/1765416279542751419#m',
#   'https://twitter.com/venkyreviews/status/1763407664287990003#m',
#   'https://twitter.com/venkyreviews/status/1758306159839092879#m',
#   'https://twitter.com/venkyreviews/status/1758266141770707153#m',
#   'https://twitter.com/venkyreviews/status/1758213432812175781#m',
#   'https://twitter.com/venkyreviews/status/1755775430508847204#m',
#   'https://twitter.com/venkyreviews/status/1755747395969675316#m',
#   'https://twitter.com/venkyreviews/status/1755727260814876828#m',
#   'https://twitter.com/venkyreviews/status/1753228621995561013#m',
#   'https://twitter.com/venkyreviews/status/1753212375140798669#m',
#   'https://twitter.com/venkyreviews/status/1753191678884647347#m',
#   'https://twitter.com/venkyreviews/status/1745871945411760239#m',
#   'https://twitter.com/venkyreviews/status/1745852220598345910#m',
#   'https://twitter.com/venkyreviews/status/1745829141755130034#m',
#   'https://twitter.com/venkyreviews/status/1745635846894551496#m',
#   'https://twitter.com/venkyreviews/status/1745635051335819676#m',
#   'https://twitter.com/venkyreviews/status/1745611027515871265#m',
#   'https://twitter.com/venkyreviews/status/1745589024960487459#m'],
#  'text': ['#Darling is a Rom-Com with no purpose or aim. The film tries to be light hearted and ends up providing a few laughs, but apart from that the film neither engages nor entertains. The comedy is artificial throughout which gives it a tedious feel. Nabha Natesh’s role irritates. Can easily skip this one!   Rating: 1.75/5',
#   '#Darling Boring 1st Half!   The comedy is artificial and does not work at all so far. Storyline is very thin so far. Need a huge 2nd half to save this one.',
#   'Showtime: #Darling',
#   '#Indian2 is an outdated and tedious movie. Though the movie tries to give honest messages, it’s done in a boring way with no proper emotion and drama at all.   Shankar tried to repeat the screenplay of his old movies but fails to recreate the magic big time. All of the emotions are completely artificial and feel like a serial drama. The film had a good start for about 20 minutes along with Senapathys entry but continues to go down hill after that.   The grandeur and production values are nice. Anirudh had no scope to give an impactful score. While you can atleast sit through the first half, the second half doesn’t give you that chance. Disaster! #Bharateeyudu2   Rating: 1.75/5',
#   '🙄🙄',
#   'Kamal Hassan is doing well. Grandeur and Production Values stand out in the first half. Anirudhs BGM is pretty ineffective so far.',
#   '#Indian2 Strictly Average 1st Half!   Film starts off well with building an emotional set-up but then goes down a predictable and routine path. So far reminds us of Shankars old screenplay structure but the routine screenplay style makes it less impactful. Needs a good 2nd half #Bharateeyudu2',
#   'Showtime: #Indian2 #Bharateeyudu2',
#   'Kudos to the whole of team of Kalki for attempting to bring a never before movie for Indian Cinema.   Nag Ashwin showed signs of both brilliance and inexperience. He was brilliant in focusing on the visuals and the finer details world. However, it felt at times he couldn’t establish a proper drama and emotional connect which would’ve elevated the movie even further.   All the cameos expect Mrunal are wasted and Vijay Deverakondas cameo is very odd.   SaNA did a very good job with the BGM in certain places but in others it was just adequate.   Prabhas had limited screen time in this one but did a good job in a fun character and gives a big fan worthy sequence in the climax   The rest of the cast especially Amitabh and Deepika have done and take up majority of the screenspace.   #kalki2898AD #Kalki',
#   '#Kalki2898AD is a larger than life Sci-FI Action Experience. The visuals and world building by Nag Ashwin are never before from Indian Cinema. However, Nag Ashwin shows some inexperience in building a proper drama and emotional connect with somewhat of a flat screenplay.   Still, he was able to manage a couple of very good blocks especially the climax which worked very well and is goosebumps worthy.   Despite some of its flaws, This is a movie that should be experienced on the big screen for the experience it offers!  Rating: 3/5',
#   'Interval Block stands out the most from the 1st half 👍 #Kalki2898AD',
#   '#Kalki2898AD Passable 1st Half!  The visuals and set up is something that has not been seen from Indian cinema which is captivating along with an interesting storyline. However, the screenplay is done in a mostly flat way so far. Prabhas has a fun character but limited screen time so far. Seems like 1st half is just a set up.',
#   'Showtime: #Kalki2898AD #Kalki',
#   '#Indian2 Trailer makes very little impact. Reminiscent of movies that came over a decade ago and doesn’t offer much of a curiosity factor. Grandeur wise looks alright but the whole cut misses a much needed X-factor. Hopefully Shankar can deliver! #Bharateeyudu2',
#   '#KALKI2898AD\u200c 2nd Trailer cut delivers again showing the visual spectacle world of Kalki in a grand manner. Gives a good glimpse into the drama/emotion that will unfold. Only gripe is the background music which is subpar and not effective at all but expecting SaNa to deliver in the movie. Raised curiosity levels!',
#   '#Manamey is an inferior movie that tries to fall into the feel good family/love drama template. The 1st half is watchable with some light hearted comedy that somewhat works. However, the 2nd half goes on endlessly without any impactful scenes. The emotional connect needed for this genre is missing coupled with underwritten characterizations. Not up to the mark!   Rating: 2.25/5',
#   'Showtime: #Manamey',
#   '#GangsofGodavari is a below par rural gangster drama that had potential with its set up but falters in execution. The first half is watchable with a couple of good mass blocks. However, the screenplay is narrated with a choppy edit that fails to build a proper drama and emotion. The second half goes for a toss with nothing much to mention. Disappointing!   Rating: 2.25/5',
#   'Showtime: #GangsofGodavari',
#   '#BujjiAndBhairava hints at a one of a kind futuristic set up that has not been seen from Indian cinema. These few episodes are more on the fun side but the massive ambition the team has is clearly seen. If the prelude vibe can be translated on the big screen then sky is the limit. This one definitely raises expectations 👍 #Kalki2898AD',
#   '#LoveMe is a silly ghost themed loved story that had an interesting core idea but the execution is mostly bad. The director fails to create suspense apart from a few bits in both halves and the screenplay is unconvincing and confusing at times. Music is ineffective. Nothing much else to mention.   Rating: 1.75/5',
#   'Showtime: #LoveMe',
#   '#Chamkila is a captivating biopic that leaves a lasting impact. Apart from a few flaws and some pacing issues, the narration of Amar Singh Chamkilas life is done in a mostly engaging way with Imtiaz Ali’s mark all over making you reflect on society. Diljit and Parineeti were excellent. Easily one of the better biopics to come from Indian Cinema. Go check it out on Netflix! #AmarSinghChamkila',
#   '#VarshangalkkuShesham is a drama full of soul and heartwarming moments throughout. It may not be everyone’s cup of tea and the runtime/slow paced  narration style is a problem at times but if you can get over that, it’s definitely a film that will take you on an emotional journey.   Vineeth Srinivasan has made another commendable film after Hridayam. Cinema fanatics will like this even more. Another praise worthy film from Malayalam Cinema!',
#   '#BadeMiyanChoteMiyan is a run-of-the-mill action film that is alright in parts but doesn’t offer anything new.   The film follows a beaten to death storyline of an antagonist being associated with Indian forces and getting betrayed thus seeking revenge.   The chemistry between Akshay and Tiger works well along with a few action blocks and Prithvirajs character.  However, the screenplay is predictable and doesn’t have a proper emotional connect and feels tiring after while as we’ve seen the same structure in many movies. Overall, a so-so time-pass film that is mostly forgettable. #BMCM   Rating: 2.5/5',
#   '#Pushpa2TheRule Teaser felt more like a glimpse but Allu Arjun’s avatar is absolutely BREATHTAKING!! Need a lot of guts to try a getup like that especially coming from Telugu Cinema. Wish they showed more content but definitely raises expectations and makes you look forward!',
#   'It is high time that VD steps out of his comfort zone and stops doing these monotonous template roles. His performance and character worked very well in GG but in this it feels repetitive and leaves no impact at all.   Parasuram tried to copy the same template structure of GG but fails in recreating the same magic. There is a scene in America where American girls think VD is a prostitute and start attacking him in the middle of Times Square in New York… not sure what Parasuram was thinking when writing scenes like that.   #FamilyStar',
#   '#FamilyStar is an inferior template rom-com family movie that has a few time-pass moments but no real emotional connection nor feel good moments.   First half is underwhelming and feels like a serial until the pre-interval. Second half starts on a more fun note but quickly turns uninteresting and preachy. Music is very ineffective. The blockbuster combo of GG disappoints. Below Par!    Rating: 2.25/5',
#   '#FamilyStar Below Par 1st Half!   So far it has a slow serial like feel to it. Few moments are entertaining but has absolutely nothing new or noteworthy yet. Need a big 2nd half!',
#   'Showtime: #FamilyStar',
#   '#TheGreatestOfAllTime North America Distribution Rights have been acquired by Hamsini Entertainment. Expected to be one of the biggest releases for Thalapathy Vijay🇺🇸 #GOAT  Previous High Budget North America Releases by Hamsini: Master, Pushpa, Beast, Valimai, and Devara (soon).',
#   '#TilluSquare A Decent Entertainer that has fun moments throughout. Tillu’s characterization and one liners have worked well again in this one along with a few fun twists. While some of the comedy lands well, some of it feels repetitive and mundane at times. Nevertheless, a pretty lighthearted entertaining watch!   Rating: 2.75-3/5',
#   '#TilluSquare Decent 1st Half!  Siddhu is back again with his trademark energetic avatar and one liners that are carrying the film. Comedy works in parts so far but feels redundant at times . Fun interval twist sets up the 2nd half well.',
#   'Showtime: #TilluSquare',
#   '#OmBheemBush is a passable comedy entertainer that is filled with contemporary references. Film runs solely on the trio, comic one liners, and a few hilarious blocks which work well. However, the storyline is almost non-existent which gives a lengthy feel to it and the film goes overboard in some places coupled with below par music. Leave aside logics and you can give this mindless comedy entertainer a try!   Rating: 2.75/5',
#   'Showtime: #OmBheemBush',
#   '#Premalu is a Breezy Rom-Com that is enjoyable throughout. It has a cliched feel to it and feels slightly dragged at times, but the lighthearted nature of the film keeps it entertaining from start to finish. Targeted towards the younger audience but can be watched with families as well. Fun watch!   Rating: 3/5',
#   '#ManjummelBoys A Heartwarming Survival Thriller that takes time to get going but once it does it keeps you on the edge of your seat. Though there is a predictability factor, the narration keeps you engaged. Performances are outstanding. Good Watch!',
#   'Showtime: #ManjummelBoys',
#   '#Hanuman North America Closing Reported Gross [Final]:  $5,312,935 - 496 Locations [₹44 Crores]  Historic Blockbuster! One of the biggest blockbusters in Telugu Cinema History!! 5th Highest Telugu Grosser of All-Time in North America.',
#   '#OperationValentine An Aerial Action Film that is narrated in a dull way where the drama does not work much and lacks an emotional high needed for a genre like this. While the attempt is commendable and there are a few satisfying moments, most of it is lifeless coupled with inferior VFX.   Rating: 2.25/5',
#   '#OoruPeruBhairavaKona A Subpar Fantasy Thriller that only works in a few parts!   The first half holds interest with a unique concept despite a dull narration style. However, the second half goes off-track after a while and into a predictable mode. Pre-Interval sequence stands out.   The curiosity that was built during the initial portions goes for a toss during the payoff scenes as the director tried a comic approach in serious situations which didn’t work well. Music is nice. Editing and the sluggish narration are the biggest drawbacks.   Rating: 2.25-2.5/5',
#   'Showtime: #OoruPeruBhairavaKona',
#   '#Animal North America Closing Reported Gross [Final]:  $15,001,042 - 739 Locations [₹124.51 Crores]  One of the biggest blockbusters of Indian Cinema!! 3rd Highest Hindi Grosser of All-Time in North America. All-Time Record in Canada.',
#   '#Eagle An Ordinary Action Thriller with a below average 1st half but a better 2nd half which saves the film to an extent!   The action sequences in the 2nd half are the biggest USP for the film and have a come out well. Production Values and Cinematography stand out.  Director drew heavy inspiration from the style of Vikram and also a bit of KGF. What works in those movies, does not work much in this one because of the tiresome narration. BGM could’ve been better. Most dialogues feel like quotes thus evoke no emotion and get rather irritating.   Action scenes and the climax portions work but the rest is so-so.  Rating: 2.5/5',
#   '#Eagle Below Average 1st half!  Interesting storyline being narrated in a tiresome way. Ravi Teja has limited screen time so far. Production Values are good.',
#   'Showtime: #Eagle',
#   '#AmbajipetaMarriageBand A Predictable and Bland Village Drama that deals with a upper/lower class storyline. Director tried to tell this story in a honest way but the formulaic approach reminds us of many movies thus lacks moments that feel truly hard hitting or emotional. Good performances by the main leads stand out. A time pass OTT watch at best!   Rating: 2.25/5',
#   '#AmbajipetaMarriageBand Average 1st Half!  Engaging initial start but goes down the path of a template village drama that is predictable and bland. Good performances are holding the film together so far.',
#   'Showtime: #AmbajipetaMarriageBand',
#   '#Saindhav A Stylish Action Drama with standout action sequences but the drama part falls flat!   The film has its heart in the right place but the narration is done in a flat way where there are very little highs and even when there is potential the music fails big time. SaNa’s BGM is the weakest part of the film and has lowered the impact of many scenes.  Few action sequences, good climax, and Venky’s performance in an action avatar standout but the rest is mediocre.   Rating: 2.5/5',
#   '#Saindhav Decent 1st Half!   First 30mins runs on a slow note but picks up after with an interesting storyline, good action sequences and performances. BGM had scope to be a lot better and is quite ineffective till now.',
#   'Showtime: #Saindhav',
#   'This movie will be a textbook on how to use  VFX with a limited budget and will inspire makers with smaller budget. Kudos to Director Prashanth Varma and the Producers for pulling off a subject like this. Teja Sajja has performed well and definitely has a bright future #Hanuman',
#   '#Hanuman A Well Made Superhero Story told with the element of Hanuman infused!   While the 1st half is engaging throughout, the 2nd half feels a little dragged at parts but the climax more than makes up for it. Very rare do we see a concept like this and the director has succeeded in pulling off a story like for the most part. BGM is good. Production Values and the VFX standout. Good Watch 👍  Rating: 3/5',
#   '#Hanuman Good 1st Half!  Director is doing a good job of mixing a superhero story with a Hanuman element while keeping commercial elements in tact. VFX is great.',
#   'Showtime: #Hanuman'],
#  'user': ['Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews',
#   'Venky Reviews'],
#  'date': ['Jul 19, 2024 · 12:25 AM UTC',
#   'Jul 18, 2024 · 11:29 PM UTC',
#   'Jul 18, 2024 · 10:00 PM UTC',
#   'Jul 12, 2024 · 12:59 AM UTC',
#   'Jul 12, 2024 · 12:30 AM UTC',
#   'Jul 11, 2024 · 11:54 PM UTC',
#   'Jul 11, 2024 · 11:51 PM UTC',
#   'Jul 11, 2024 · 9:54 PM UTC',
#   'Jun 26, 2024 · 10:04 PM UTC',
#   'Jun 26, 2024 · 9:56 PM UTC',
#   'Jun 26, 2024 · 8:17 PM UTC',
#   'Jun 26, 2024 · 8:02 PM UTC',
#   'Jun 26, 2024 · 6:14 PM UTC',
#   'Jun 25, 2024 · 2:59 PM UTC',
#   'Jun 21, 2024 · 3:30 PM UTC',
#   'Jun 7, 2024 · 1:13 AM UTC',
#   'Jun 6, 2024 · 9:20 PM UTC',
#   'May 31, 2024 · 1:07 AM UTC',
#   'May 30, 2024 · 10:37 PM UTC',
#   'May 30, 2024 · 7:15 PM UTC',
#   'May 25, 2024 · 12:48 AM UTC',
#   'May 24, 2024 · 9:58 PM UTC',
#   'Apr 13, 2024 · 6:57 AM UTC',
#   'Apr 13, 2024 · 1:34 AM UTC',
#   'Apr 10, 2024 · 5:47 PM UTC',
#   'Apr 8, 2024 · 5:49 AM UTC',
#   'Apr 4, 2024 · 9:41 PM UTC',
#   'Apr 4, 2024 · 9:37 PM UTC',
#   'Apr 4, 2024 · 8:14 PM UTC',
#   'Apr 4, 2024 · 6:51 PM UTC',
#   'Apr 2, 2024 · 2:31 AM UTC',
#   'Mar 29, 2024 · 1:47 AM UTC',
#   'Mar 29, 2024 · 12:31 AM UTC',
#   'Mar 28, 2024 · 10:33 PM UTC',
#   'Mar 22, 2024 · 2:59 AM UTC',
#   'Mar 21, 2024 · 8:59 PM UTC',
#   'Mar 10, 2024 · 5:18 AM UTC',
#   'Mar 9, 2024 · 2:01 AM UTC',
#   'Mar 8, 2024 · 11:12 PM UTC',
#   'Mar 6, 2024 · 4:36 PM UTC',
#   'Mar 1, 2024 · 3:35 AM UTC',
#   'Feb 16, 2024 · 1:43 AM UTC',
#   'Feb 15, 2024 · 11:04 PM UTC',
#   'Feb 15, 2024 · 7:35 PM UTC',
#   'Feb 9, 2024 · 2:07 AM UTC',
#   'Feb 9, 2024 · 12:16 AM UTC',
#   'Feb 8, 2024 · 10:56 PM UTC',
#   'Feb 2, 2024 · 1:27 AM UTC',
#   'Feb 2, 2024 · 12:22 AM UTC',
#   'Feb 1, 2024 · 11:00 PM UTC',
#   'Jan 12, 2024 · 6:14 PM UTC',
#   'Jan 12, 2024 · 4:56 PM UTC',
#   'Jan 12, 2024 · 3:24 PM UTC',
#   'Jan 12, 2024 · 2:36 AM UTC',
#   'Jan 12, 2024 · 2:33 AM UTC',
#   'Jan 12, 2024 · 12:57 AM UTC',
#   'Jan 11, 2024 · 11:30 PM UTC'],
#  'likes': [508,
#   423,
#   2256,
#   3779,
#   1221,
#   600,
#   1992,
#   2979,
#   2482,
#   8355,
#   3304,
#   9977,
#   11584,
#   972,
#   3435,
#   676,
#   1046,
#   963,
#   1954,
#   3866,
#   432,
#   1054,
#   258,
#   1192,
#   876,
#   4105,
#   735,
#   1565,
#   3255,
#   1200,
#   1133,
#   1346,
#   3050,
#   555,
#   704,
#   861,
#   1764,
#   1169,
#   416,
#   798,
#   677,
#   421,
#   561,
#   804,
#   1238,
#   1797,
#   470,
#   481,
#   410,
#   584,
#   2464,
#   4137,
#   1837,
#   1391,
#   3794,
#   3132,
#   513],
#  'quotes': [25,
#   3,
#   1,
#   503,
#   47,
#   11,
#   27,
#   8,
#   29,
#   236,
#   39,
#   143,
#   127,
#   10,
#   20,
#   24,
#   2,
#   41,
#   1,
#   16,
#   18,
#   4,
#   4,
#   7,
#   64,
#   14,
#   73,
#   131,
#   85,
#   24,
#   15,
#   27,
#   9,
#   0,
#   8,
#   8,
#   54,
#   9,
#   0,
#   22,
#   25,
#   6,
#   1,
#   14,
#   46,
#   15,
#   5,
#   22,
#   2,
#   1,
#   111,
#   52,
#   57,
#   5,
#   41,
#   6,
#   1],
#  'retweets': [51,
#   26,
#   97,
#   706,
#   64,
#   60,
#   171,
#   180,
#   745,
#   2209,
#   816,
#   1259,
#   1193,
#   92,
#   1042,
#   60,
#   51,
#   105,
#   79,
#   1342,
#   37,
#   33,
#   26,
#   115,
#   223,
#   1069,
#   129,
#   273,
#   379,
#   130,
#   323,
#   213,
#   250,
#   28,
#   70,
#   45,
#   195,
#   104,
#   23,
#   153,
#   54,
#   35,
#   16,
#   158,
#   153,
#   131,
#   28,
#   58,
#   24,
#   29,
#   316,
#   592,
#   236,
#   287,
#   860,
#   501,
#   40],
#  'comments': [27,
#   5,
#   10,
#   301,
#   51,
#   5,
#   17,
#   15,
#   33,
#   256,
#   46,
#   168,
#   203,
#   25,
#   56,
#   27,
#   8,
#   46,
#   9,
#   54,
#   16,
#   6,
#   5,
#   17,
#   86,
#   43,
#   26,
#   54,
#   86,
#   52,
#   16,
#   37,
#   15,
#   3,
#   18,
#   22,
#   49,
#   11,
#   3,
#   17,
#   29,
#   17,
#   2,
#   14,
#   78,
#   31,
#   6,
#   37,
#   8,
#   4,
#   105,
#   47,
#   58,
#   6,
#   61,
#   23,
#   10]}

# %%
import pandas as pd
df = pd.DataFrame(data)
df.head()
# Out:
#                                                 link  \
# 0  https://twitter.com/venkyreviews/status/181409...
# 1  https://twitter.com/venkyreviews/status/181408...
# 2  https://twitter.com/venkyreviews/status/181405...
# 3  https://twitter.com/venkyreviews/status/181156...
# 4  https://twitter.com/venkyreviews/status/181155...
#
#                                                 text           user  \
# 0  #Darling is a Rom-Com with no purpose or aim. ...  Venky Reviews
# 1  #Darling Boring 1st Half!   The comedy is arti...  Venky Reviews
# 2                                 Showtime: #Darling  Venky Reviews
# 3  #Indian2 is an outdated and tedious movie. Tho...  Venky Reviews
# 4                                                 🙄🙄  Venky Reviews
#
#                           date  likes  quotes  retweets  comments
# 0  Jul 19, 2024 · 12:25 AM UTC    508      25        51        27
# 1  Jul 18, 2024 · 11:29 PM UTC    423       3        26         5
# 2  Jul 18, 2024 · 10:00 PM UTC   2256       1        97        10
# 3  Jul 12, 2024 · 12:59 AM UTC   3779     503       706       301
# 4  Jul 12, 2024 · 12:30 AM UTC   1221      47        64        51

# %%
df.to_csv("nlp_review.csv")
